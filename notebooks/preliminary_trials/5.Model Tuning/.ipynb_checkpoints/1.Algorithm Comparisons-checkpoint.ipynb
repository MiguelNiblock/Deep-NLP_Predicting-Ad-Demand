# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import cyrtranslit
from sklearn import preprocessing, model_selection, metrics, feature_selection, ensemble, linear_model, neural_network
from sklearn.pipeline import Pipeline
import lightgbm as lgb
color = sns.color_palette()
# %matplotlib inline

# %%
train = pd.read_pickle('../train.pkl',compression='zip')

# %%
features = pd.read_pickle('../4.NLP Discretized Term Decomposition/allfeatures.pkl',compression='zip')

# %%
y = train.deal_probability
X_dev,X_val,y_dev,y_val = model_selection.train_test_split(features,y)

# %% [markdown]
# # LGB

# %%
params = {
        "objective" : "regression",
        "metric" : "rmse",
        "num_leaves" : 30,
        "learning_rate" : 0.1,
        "bagging_fraction" : 0.7,
        "feature_fraction" : 0.7,
        "bagging_frequency" : 5,
        "bagging_seed" : 2018,
        "verbosity" : -1
    }
    
lgtrain = lgb.Dataset(X_dev, label=y_dev)
lgval = lgb.Dataset(X_val, label=y_val)
evals_result = {}

# %%
model = lgb.train(params, lgtrain, 1000, valid_sets=[lgval], early_stopping_rounds=100, verbose_eval=20, evals_result=evals_result)
# Out:
# Training until validation scores don't improve for 100 rounds.
# [20]	valid_0's rmse: 0.220893
# [40]	valid_0's rmse: 0.21848
# [60]	valid_0's rmse: 0.217721
# [80]	valid_0's rmse: 0.217248
# [100]	valid_0's rmse: 0.216889
# [120]	valid_0's rmse: 0.216684
# [140]	valid_0's rmse: 0.216524
# [160]	valid_0's rmse: 0.216414
# [180]	valid_0's rmse: 0.21632
# [200]	valid_0's rmse: 0.216208
# [220]	valid_0's rmse: 0.216157
# [240]	valid_0's rmse: 0.216097
# [260]	valid_0's rmse: 0.216027
# [280]	valid_0's rmse: 0.215966
# [300]	valid_0's rmse: 0.215926
# [320]	valid_0's rmse: 0.215883
# [340]	valid_0's rmse: 0.215848
# [360]	valid_0's rmse: 0.215816
# [380]	valid_0's rmse: 0.215792
# [400]	valid_0's rmse: 0.215776
# [420]	valid_0's rmse: 0.215738
# [440]	valid_0's rmse: 0.215717
# [460]	valid_0's rmse: 0.215692
# [480]	valid_0's rmse: 0.215674
# [500]	valid_0's rmse: 0.215651
# [520]	valid_0's rmse: 0.215643
# [540]	valid_0's rmse: 0.215618
# [560]	valid_0's rmse: 0.215599
# [580]	valid_0's rmse: 0.21557
# [600]	valid_0's rmse: 0.215553
# [620]	valid_0's rmse: 0.215549
# [640]	valid_0's rmse: 0.215528
# [660]	valid_0's rmse: 0.215507
# [680]	valid_0's rmse: 0.215496
# [700]	valid_0's rmse: 0.215492
# [720]	valid_0's rmse: 0.215477
# [740]	valid_0's rmse: 0.215463
# [760]	valid_0's rmse: 0.215452
# [780]	valid_0's rmse: 0.215433
# [800]	valid_0's rmse: 0.215423
# [820]	valid_0's rmse: 0.21542
# [840]	valid_0's rmse: 0.215419
# [860]	valid_0's rmse: 0.215416
# [880]	valid_0's rmse: 0.215414
# [900]	valid_0's rmse: 0.215417
# [920]	valid_0's rmse: 0.215421
# [940]	valid_0's rmse: 0.215413
# [960]	valid_0's rmse: 0.215405
# [980]	valid_0's rmse: 0.215399
# [1000]	valid_0's rmse: 0.215392
# Did not meet early stopping. Best iteration is:
# [987]	valid_0's rmse: 0.215389

# %%
fig, ax = plt.subplots(figsize=(12,18))
lgb.plot_importance(model, max_num_features=50, height=0.8, ax=ax)
ax.grid(False)
plt.title("LightGBM - Feature Importance", fontsize=15)
plt.show()

# %%
pred = model.predict(X_val, num_iteration=model.best_iteration)

# %%
print('Less than zero:',sum(pred<0))
print('Over one:',sum(pred>1))
# Out:
# Less than zero: 5448
# Over one: 37

# %% [markdown]
# # Limiting Values to Target Range

# %%
pred[pred>1] = 1
pred[pred<0] = 0

# %%
metrics.mean_squared_error(y_val,pred)**0.5
# Out:
# 0.2153720159675269

# %%
residual = y_val-pred

# %% [markdown]
# # Residual Analysis

# %%
plt.hist(residual)
plt.show()

# %%
plt.scatter(pred,residual)
plt.show()

# %% [markdown]
# # MLPRegressor

# %%
mlp = neural_network.MLPRegressor(verbose=True,hidden_layer_sizes=(100,10))

# %%
mlp.fit(X_dev,y_dev)
# Out:
# Iteration 1, loss = 0.02670253
# Iteration 2, loss = 0.02405359
# Iteration 3, loss = 0.02389220
# Iteration 4, loss = 0.02381313
# Iteration 5, loss = 0.02376108
# Iteration 6, loss = 0.02372320
# Iteration 7, loss = 0.02369870
# Iteration 8, loss = 0.02367148
# Iteration 9, loss = 0.02365797
# Iteration 10, loss = 0.02363469
# Iteration 11, loss = 0.02361868
# Iteration 12, loss = 0.02360374
# Iteration 13, loss = 0.02359440
# Iteration 14, loss = 0.02357909
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 10), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=True, warm_start=False)

# %%
pred = mlp.predict(X_val)

# %%
print('Less than zero:',sum(pred<0))
print('Over one:',sum(pred>1))
# Out:
# Less than zero: 4300
# Over one: 75

# %%
pred[pred>1] = 1
pred[pred<0] = 0

# %%
metrics.mean_squared_error(y_val,pred)**0.5
# Out:
# 0.21760551141506157

# %% [markdown]
# # Keras

# %%
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.layers import LSTM, Input, TimeDistributed
from keras.models import Model
from keras.optimizers import RMSprop

# Import the backend
from keras import backend as K

# %%
model = Sequential()
model.add(Dense(64, activation='relu', input_dim=52))
model.add(Dense(1, activation='relu'))

model.summary()

model.compile(loss='mean_squared_error',
              optimizer='sgd',
              metrics=['accuracy'])
model.fit(X_dev,y_dev,epochs=10,verbose=1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_141 (Dense)            (None, 64)                3392
# _________________________________________________________________
# dense_142 (Dense)            (None, 1)                 65
# =================================================================
# Total params: 3,457
# Trainable params: 3,457
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1127568/1127568 [==============================] - 110s 97us/step - loss: 0.0578 - acc: 0.6466
# Epoch 2/10
# 1127568/1127568 [==============================] - 97s 86us/step - loss: 0.0500 - acc: 0.6481
# Epoch 3/10
# 1127568/1127568 [==============================] - 103s 92us/step - loss: 0.0495 - acc: 0.6483
# Epoch 4/10
# 1127568/1127568 [==============================] - 80s 71us/step - loss: 0.0491 - acc: 0.6484
# Epoch 5/10
# 1127568/1127568 [==============================] - 99s 87us/step - loss: 0.0489 - acc: 0.6486
# Epoch 6/10
# 1127568/1127568 [==============================] - 114s 101us/step - loss: 0.0488 - acc: 0.6486
# Epoch 7/10
# 1127568/1127568 [==============================] - 103s 91us/step - loss: 0.0486 - acc: 0.6487
# Epoch 8/10
# 1127568/1127568 [==============================] - 78s 69us/step - loss: 0.0485 - acc: 0.6487
# Epoch 9/10
# 1127568/1127568 [==============================] - 75s 66us/step - loss: 0.0484 - acc: 0.6488
# Epoch 10/10
# 1127568/1127568 [==============================] - 83s 74us/step - loss: 0.0483 - acc: 0.6488

# %%
pred = model.predict(X_val)

# %%
print('Less than zero:',sum(pred<0))
print('Over one:',sum(pred>1))
# Out:
# Less than zero: [0]
# Over one: [209]

# %%
pred[pred>1] = 1
pred[pred<0] = 0

# %%
metrics.mean_squared_error(y_val,pred)**0.5
# Out:
# 0.21917734169794267
