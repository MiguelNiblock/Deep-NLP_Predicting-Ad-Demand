# %% [markdown]
# # Test
# ```
# <iframe src="https://onedrive.live.com/embed?cid=62B3CEE436FDB342&resid=62B3CEE436FDB342%21106&authkey=AAF_zwBmWjNhNGQ" width="98" height="120" frameborder="0" scrolling="no"></iframe>
# ```
#
# # Train
# ```
# <iframe src="https://onedrive.live.com/embed?cid=62B3CEE436FDB342&resid=62B3CEE436FDB342%21107&authkey=AEh-8Y6p9SC7FK0" width="98" height="120" frameborder="0" scrolling="no"></iframe>
# ```

# %%
import pandas as pd

# %%
pd.read_csv('https://onedrive.live.com/download?cid=62B3CEE436FDB342&resid=62B3CEE436FDB342%21106&authkey=AAF_zwBmWjNhNGQ',
           compression='zip')
# Out:
#              item_id       user_id                   region              city  \
# 0       6544e41a8817  dbe73ad6e4b5    Волгоградская область         Волгоград
# 1       65b9484d670f  2e11806abe57     Свердловская область       Нижняя Тура
# 2       8bab230b2ecd  0b850bbebb10    Новосибирская область            Бердск
# 3       8e348601fefc  5f1d5c3ce0da      Саратовская область           Саратов
# 4       8bd2fe400b89  23e2d97bfc7f     Оренбургская область           Бузулук
# 5       c63dbd6c657f  c2a632af2602       Ростовская область    Ростов-на-Дону
# 6       6d1a410df86e  b239811ad530     Оренбургская область          Оренбург
# 7       e8d3e7922b80  d85fa02e6341  Калининградская область       Калининград
# 8       2bc1ab208462  ae6586719bec    Новосибирская область       Новосибирск
# 9       7e05d77a9181  30ad26d633ef     Свердловская область         Полевской
# 10      e2ec19a3ca2b  cf6fadee4837            Пермский край             Пермь
# ...

# %%
https://www.kaggle.com/c/avito-demand-prediction/download/test.csv
